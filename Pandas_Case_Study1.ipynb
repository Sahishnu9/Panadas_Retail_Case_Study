# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Customer = pd.read_csv('C:/Users/Sai Sahishnu/Desktop/life robber/Customer.csv')
Customer
# Out:
#       customer_Id         DOB Gender  city_code
# 0          268408  02-01-1970      M        4.0
# 1          269696  07-01-1970      F        8.0
# 2          268159  08-01-1970      F        8.0
# 3          270181  10-01-1970      F        2.0
# 4          268073  11-01-1970      M        1.0
# ...           ...         ...    ...        ...
# 5642       274474  19-12-1992      M        2.0
# 5643       267666  24-12-1992      M        6.0
# 5644       270476  25-12-1992      F        3.0
# 5645       269626  27-12-1992      F        5.0
# 5646       274308  29-12-1992      F        5.0
#
# [5647 rows x 4 columns]

# %%
Transaction = pd.read_csv('C:/Users/Sai Sahishnu/Desktop/life robber/Transactions.csv')
Transaction
# Out:
#        transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351  28-02-2014                 1              1
# 1         29258453508   270384  27-02-2014                 5              3
# 2         51750724947   273420  24-02-2014                 6              5
# 3         93274880719   271509  24-02-2014                11              6
# 4         51750724947   273420  23-02-2014                 6              5
# ...               ...      ...         ...               ...            ...
# 23048     94340757522   274550  25-01-2011                12              5
# 23049     89780862956   270022  25-01-2011                 4              1
# 23050     85115299378   271020  25-01-2011                 2              6
# 23051     72870271171   270911  25-01-2011                11              5
# 23052     77960931771   271961  25-01-2011                11              5
#
#        Qty  Rate      Tax  total_amt Store_type
# ...

# %%
Product_Hierarchy = pd.read_csv('C:/Users/Sai Sahishnu/Desktop/life robber/prod_cat_info.csv')
Product_Hierarchy
# Out:
#     prod_cat_code          prod_cat  prod_sub_cat_code          prod_subcat
# 0               1          Clothing                  4                 Mens
# 1               1          Clothing                  1                Women
# 2               1          Clothing                  3                 Kids
# 3               2          Footwear                  1                 Mens
# 4               2          Footwear                  3                Women
# 5               2          Footwear                  4                 Kids
# 6               3       Electronics                  4              Mobiles
# 7               3       Electronics                  5            Computers
# 8               3       Electronics                  8  Personal Appliances
# 9               3       Electronics                  9              Cameras
# 10              3       Electronics                 10      Audio and video
# ...

# %% [markdown]
# #1. Merge the datasets Customers, Product Hierarchy and Transactions as Customer_Final. Ensure to
# keep all customers who have done transactions with us and select the join type accordingly.

# %%
Customer_ = pd.merge(left = Customer,right = Transaction,how = "left",left_on = 'customer_Id',right_on = 'cust_id')
Customer_
# Out:
#        customer_Id         DOB Gender  city_code  transaction_id   cust_id  \
# 0           268408  02-01-1970      M        4.0    8.724384e+10  268408.0
# 1           268408  02-01-1970      M        4.0    1.619787e+10  268408.0
# 2           268408  02-01-1970      M        4.0    1.619787e+10  268408.0
# 3           268408  02-01-1970      M        4.0    2.881014e+10  268408.0
# 4           268408  02-01-1970      M        4.0    6.463344e+10  268408.0
# ...            ...         ...    ...        ...             ...       ...
# 23189       269626  27-12-1992      F        5.0    7.136903e+10  269626.0
# 23190       269626  27-12-1992      F        5.0    9.413405e+10  269626.0
# 23191       274308  29-12-1992      F        5.0    2.620869e+10  274308.0
# 23192       274308  29-12-1992      F        5.0    5.735882e+10  274308.0
# 23193       274308  29-12-1992      F        5.0    5.816054e+10  274308.0
#
# ...

# %%
Customer_Final = pd.merge(left = Customer_ ,right = Product_Hierarchy,how = 'left', left_on = ['prod_subcat_code', 'prod_cat_code'],right_on = ['prod_cat_code','prod_sub_cat_code'])
Customer_Final
# Out:
#        customer_Id         DOB Gender  city_code  transaction_id   cust_id  \
# 0           268408  02-01-1970      M        4.0    8.724384e+10  268408.0
# 1           268408  02-01-1970      M        4.0    1.619787e+10  268408.0
# 2           268408  02-01-1970      M        4.0    1.619787e+10  268408.0
# 3           268408  02-01-1970      M        4.0    2.881014e+10  268408.0
# 4           268408  02-01-1970      M        4.0    6.463344e+10  268408.0
# ...            ...         ...    ...        ...             ...       ...
# 23189       269626  27-12-1992      F        5.0    7.136903e+10  269626.0
# 23190       269626  27-12-1992      F        5.0    9.413405e+10  269626.0
# 23191       274308  29-12-1992      F        5.0    2.620869e+10  274308.0
# 23192       274308  29-12-1992      F        5.0    5.735882e+10  274308.0
# 23193       274308  29-12-1992      F        5.0    5.816054e+10  274308.0
#
# ...

# %% [markdown]
# #2. Prepare a summary report for the merged data set.
#  a. Get the column names and their corresponding data types
#  b. Top/Bottom 10 observations
#  c. “Five-number summary” for continuous variables (min, Q1, median, Q3 and max)
#  d. Frequency tables for all the categorical variables

# %%
Customer_Final.columns
# Out:
# Index(['customer_Id', 'DOB', 'Gender', 'city_code', 'transaction_id',
#        'cust_id', 'tran_date', 'prod_subcat_code', 'prod_cat_code_x', 'Qty',
#        'Rate', 'Tax', 'total_amt', 'Store_type', 'prod_cat_code_y', 'prod_cat',
#        'prod_sub_cat_code', 'prod_subcat'],
#       dtype='object')

# %%
Customer_Final.dtypes
# Out:
# customer_Id            int64
# DOB                   object
# Gender                object
# city_code            float64
# transaction_id       float64
# cust_id              float64
# tran_date             object
# prod_subcat_code     float64
# prod_cat_code_x      float64
# Qty                  float64
# Rate                 float64
# Tax                  float64
# total_amt            float64
# Store_type            object
# prod_cat_code_y      float64
# prod_cat              object
# prod_sub_cat_code    float64
# prod_subcat           object
# dtype: object

# %%
Customer_Final.head(10)
# Out:
#    customer_Id         DOB Gender  city_code  transaction_id   cust_id  \
# 0       268408  02-01-1970      M        4.0    8.724384e+10  268408.0
# 1       268408  02-01-1970      M        4.0    1.619787e+10  268408.0
# 2       268408  02-01-1970      M        4.0    1.619787e+10  268408.0
# 3       268408  02-01-1970      M        4.0    2.881014e+10  268408.0
# 4       268408  02-01-1970      M        4.0    6.463344e+10  268408.0
# 5       268408  02-01-1970      M        4.0    5.690286e+10  268408.0
# 6       268408  02-01-1970      M        4.0    5.684453e+10  268408.0
# 7       268408  02-01-1970      M        4.0    1.951606e+10  268408.0
# 8       268408  02-01-1970      M        4.0    1.264450e+10  268408.0
# 9       268408  02-01-1970      M        4.0    6.331455e+10  268408.0
#
#     tran_date  prod_subcat_code  prod_cat_code_x  Qty    Rate      Tax  \
# 0  13-01-2014               7.0              5.0  5.0   187.0   98.175
# ...

# %%
Customer_Final.tail(10)
# Out:
#        customer_Id         DOB Gender  city_code  transaction_id   cust_id  \
# 23184       270476  25-12-1992      F        3.0    7.803441e+10  270476.0
# 23185       270476  25-12-1992      F        3.0    3.359888e+09  270476.0
# 23186       270476  25-12-1992      F        3.0    2.288339e+10  270476.0
# 23187       270476  25-12-1992      F        3.0    1.972519e+10  270476.0
# 23188       270476  25-12-1992      F        3.0    8.547516e+10  270476.0
# 23189       269626  27-12-1992      F        5.0    7.136903e+10  269626.0
# 23190       269626  27-12-1992      F        5.0    9.413405e+10  269626.0
# 23191       274308  29-12-1992      F        5.0    2.620869e+10  274308.0
# 23192       274308  29-12-1992      F        5.0    5.735882e+10  274308.0
# 23193       274308  29-12-1992      F        5.0    5.816054e+10  274308.0
#
#         tran_date  prod_subcat_code  prod_cat_code_x  Qty    Rate      Tax  \
# ...

# %%
Customer_Final.describe()
# Out:
#          customer_Id     city_code  transaction_id        cust_id  \
# count   23194.000000  23186.000000    2.305300e+04   23053.000000
# mean   271022.609296      5.480204    5.007348e+10  271021.746497
# std      2431.350129      2.863884    2.898194e+10    2431.692059
# min    266783.000000      1.000000    3.268991e+06  266783.000000
# 25%    268936.000000      3.000000    2.493864e+10  268935.000000
# 50%    270981.000000      5.000000    5.009313e+10  270980.000000
# 75%    273115.750000      8.000000    7.533000e+10  273114.000000
# max    275265.000000     10.000000    9.998755e+10  275265.000000
#
#        prod_subcat_code  prod_cat_code_x           Qty          Rate  \
# count      23053.000000     23053.000000  23053.000000  23053.000000
# mean           6.149091         3.763632      2.432395    636.369713
# std            3.726372         1.677016      2.268406    622.363498
# min            1.000000         1.000000     -5.000000  -1499.000000
# ...

# %%
Customer_Final.loc[ :,Customer_Final.dtypes == 'object'].describe()
# Out:
#                DOB Gender   tran_date Store_type  prod_cat prod_subcat
# count        23194  23185       23053      23053      5959        5959
# unique        4056      2        1129          4         4           4
# top     17-09-1982      M  13-07-2011     e-Shop  Clothing       Women
# freq            32  11877          35       9311      2008        2000

# %% [markdown]
# 3. Generate histograms for all continuous variables and frequency bars for categorical variables

# %%
cont_var = Customer_Final.select_dtypes(['int64','float64'])
cat_var = Customer_Final.select_dtypes('object')

# %%
cont_var.hist(figsize = (30,20))
plt.show()

# %%
sns.countplot(cat_var['Gender'])
plt.show()
# Out:
# C:\Users\Sai Sahishnu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(cat_var['Store_type'])
plt.show()
# Out:
# C:\Users\Sai Sahishnu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(cat_var['prod_cat'])
plt.show()
# Out:
# C:\Users\Sai Sahishnu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(cat_var['prod_subcat'])

plt.show()
# Out:
# C:\Users\Sai Sahishnu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# 4. Calculate the following information using the merged dataset :
#  a. Time period of the available transaction data
#  b. Count of transactions where the total amount of transaction was negative

# %%
Customer_Final["tran_date"]= pd.to_datetime(Customer_Final['tran_date'])

# %%
max = Customer_Final['tran_date'].max()
min = Customer_Final['tran_date'].min()

# %%
pd.Timestamp.strftime(min,format = '%d-%m-%Y') + ' to ' + pd.Timestamp.strftime(max,format = '%d-%m-%Y')
# Out:
# '02-01-2011 to 02-12-2014'

# %%
Customer_Final
# Out:
#        customer_Id         DOB Gender  city_code  transaction_id   cust_id  \
# 0           268408  02-01-1970      M        4.0    8.724384e+10  268408.0
# 1           268408  02-01-1970      M        4.0    1.619787e+10  268408.0
# 2           268408  02-01-1970      M        4.0    1.619787e+10  268408.0
# 3           268408  02-01-1970      M        4.0    2.881014e+10  268408.0
# 4           268408  02-01-1970      M        4.0    6.463344e+10  268408.0
# ...            ...         ...    ...        ...             ...       ...
# 23189       269626  27-12-1992      F        5.0    7.136903e+10  269626.0
# 23190       269626  27-12-1992      F        5.0    9.413405e+10  269626.0
# 23191       274308  29-12-1992      F        5.0    2.620869e+10  274308.0
# 23192       274308  29-12-1992      F        5.0    5.735882e+10  274308.0
# 23193       274308  29-12-1992      F        5.0    5.816054e+10  274308.0
#
# ...

# %%
Customer_Final.loc[Customer_Final['total_amt']<0,'transaction_id'].count()
# Out:
# 2177

# %% [markdown]
# 5. Analyze which product categories are more popular among females vs male customers.

# %%
prod_gender = Customer_Final.groupby(['Gender','prod_cat'])[['Qty']].sum().reset_index
prod_gender
# Out:
# <bound method DataFrame.reset_index of                        Qty
# Gender prod_cat
# F      Bags         2291.0
#        Books        1140.0
#        Clothing     2233.0
#        Electronics  1113.0
# M      Bags         2421.0
#        Books        1255.0
#        Clothing     2530.0
#        Electronics  1335.0>

# %% [markdown]
# 6. Which City code has the maximum customers and what was the percentage of customers from that city?

# %%
Cust = Customer_Final.groupby(['city_code'])['customer_Id'].count().sort_values(ascending = False)
Cust
# Out:
# city_code
# 4.0     2435
# 3.0     2430
# 5.0     2376
# 7.0     2368
# 10.0    2345
# 8.0     2341
# 2.0     2288
# 1.0     2274
# 9.0     2192
# 6.0     2137
# Name: customer_Id, dtype: int64

# %%
percentage = round((Cust[5.0]/Cust.sum())*100,2)
percentage
# Out:
# 10.25

# %% [markdown]
# 7. Which store type sells the maximum products by value and by quantity?

# %%
 Customer_Final.groupby(['Store_type'])['Qty','Rate'].sum().sort_values(by = 'Qty',ascending = False)
# Out:
# <ipython-input-144-4880dfff5765>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Customer_Final.groupby(['Store_type'])['Qty','Rate'].sum().sort_values(by = 'Qty',ascending = False)
#                     Qty       Rate
# Store_type
# e-Shop          22763.0  5941001.0
# MBR             11194.0  2953253.0
# Flagship store  11133.0  2941557.0
# TeleShop        10984.0  2834420.0

# %% [markdown]
# 8. What was the total amount earned from the "Electronics" and "Clothing" categories from
# Flagship Stores?

# %%
store_grp = round(Customer_Final.pivot_table(index = 'prod_cat',columns = 'Store_type',values = 'total_amt',aggfunc = 'sum'),2)
store_grp
# Out:
# Store_type   Flagship store        MBR   TeleShop      e-Shop
# prod_cat
# Bags              818984.01  807798.09  721356.15  1709843.85
# Books             487279.58  421483.46  358305.09   823048.20
# Clothing          823271.41  907508.88  887129.36  1588994.42
# Electronics       353131.48  453942.84  432968.84   860804.95

# %%
store_grp.loc[['Clothing','Electronics'],'Flagship store'].sum()
# Out:
# 1176402.8900000001

# %% [markdown]
# 9. What was the total amount earned from "Male" customers under the "Electronics" category?

# %%
gender_grp = round(Customer_Final.pivot_table(index = 'prod_cat',columns = 'Gender',values = 'total_amt',aggfunc = 'sum'),2)
gender_grp
# Out:
# Gender                F           M
# prod_cat
# Bags         1994709.54  2063272.58
# Books         998699.00  1091417.34
# Clothing     1985022.00  2221882.06
# Electronics   945524.19  1155323.91

# %%
gender_grp.loc['Electronics','M']
# Out:
# 1155323.91

# %% [markdown]
# 10. How many customers have more than 10 unique transactions, after removing all transactions
# which have any negative amounts?

# %%
positive_trans = Customer_Final.loc[Customer_Final['total_amt']>0,:]
positive_trans
# Out:
#        customer_Id         DOB Gender  city_code  transaction_id   cust_id  \
# 0           268408  02-01-1970      M        4.0    8.724384e+10  268408.0
# 2           268408  02-01-1970      M        4.0    1.619787e+10  268408.0
# 3           268408  02-01-1970      M        4.0    2.881014e+10  268408.0
# 4           268408  02-01-1970      M        4.0    6.463344e+10  268408.0
# 5           268408  02-01-1970      M        4.0    5.690286e+10  268408.0
# ...            ...         ...    ...        ...             ...       ...
# 23189       269626  27-12-1992      F        5.0    7.136903e+10  269626.0
# 23190       269626  27-12-1992      F        5.0    9.413405e+10  269626.0
# 23191       274308  29-12-1992      F        5.0    2.620869e+10  274308.0
# 23192       274308  29-12-1992      F        5.0    5.735882e+10  274308.0
# 23193       274308  29-12-1992      F        5.0    5.816054e+10  274308.0
#
# ...

# %%
unique_trans = positive_trans.groupby(['customer_Id','prod_cat','prod_subcat'])['transaction_id'].count().reset_index()
unique_trans
# Out:
#       customer_Id     prod_cat prod_subcat  transaction_id
# 0          266783         Bags        Mens               2
# 1          266785     Clothing        Mens               1
# 2          266788     Clothing        Mens               1
# 3          266794         Bags       Women               1
# 4          266794     Clothing        Mens               1
# ...           ...          ...         ...             ...
# 4964       275252     Clothing       Women               1
# 4965       275261         Bags       Women               1
# 4966       275261  Electronics   Computers               1
# 4967       275262         Bags        Mens               1
# 4968       275265     Clothing        Mens               1
#
# [4969 rows x 4 columns]

# %%
unique_trans_count = unique_trans.groupby('customer_Id')['transaction_id'].count().reset_index()
unique_trans_count
# Out:
#       customer_Id  transaction_id
# 0          266783               1
# 1          266785               1
# 2          266788               1
# 3          266794               2
# 4          266799               1
# ...           ...             ...
# 3444       275247               1
# 3445       275252               3
# 3446       275261               2
# 3447       275262               1
# 3448       275265               1
#
# [3449 rows x 2 columns]

# %%
unique_trans_count[unique_trans_count['transaction_id']>10]
# Out:
# Empty DataFrame
# Columns: [customer_Id, transaction_id]
# Index: []

# %% [markdown]
# 11. For all customers aged between 25 - 35, find out:
#  a. What was the total amount spent for “Electronics” and “Books” product categories?
#  b. What was the total amount spent by these customers between 1st Jan, 2014 to 1st Mar, 2014?

# %%
Customer_Final["DOB"]= pd.to_datetime(Customer_Final['DOB'])

# %%
now = pd.Timestamp('now')
Customer_Final['DOB']= pd.to_datetime(Customer_Final['DOB'],format = '%m%d%y')
Customer_Final['DOB'] = Customer_Final['DOB'].where(Customer_Final['DOB']<now,Customer_Final['DOB']-np.timedelta64(100,'Y'))
Customer_Final['AGE']= (now-Customer_Final['DOB']).astype('<m8[Y]')

# %%
Customer_Final.head()
# Out:
#    customer_Id        DOB Gender  city_code  transaction_id   cust_id  \
# 0       268408 1970-02-01      M        4.0    8.724384e+10  268408.0
# 1       268408 1970-02-01      M        4.0    1.619787e+10  268408.0
# 2       268408 1970-02-01      M        4.0    1.619787e+10  268408.0
# 3       268408 1970-02-01      M        4.0    2.881014e+10  268408.0
# 4       268408 1970-02-01      M        4.0    6.463344e+10  268408.0
#
#    tran_date  prod_subcat_code  prod_cat_code_x  Qty   Rate      Tax  \
# 0 2014-01-13               7.0              5.0  5.0  187.0   98.175
# 1 2013-12-16               1.0              4.0 -5.0 -210.0  110.250
# 2 2013-12-12               1.0              4.0  5.0  210.0  110.250
# 3 2013-02-09              10.0              6.0  2.0  813.0  170.730
# 4 2013-06-05               4.0              2.0  3.0  312.0   98.280
#
#    total_amt      Store_type  prod_cat_code_y  prod_cat  prod_sub_cat_code  \
# ...

# %%
Customer_Final['Age_cat']= pd.cut(Customer_Final['AGE'],bins = [24,35,46,57],labels = ['25-35','36-46','47-57'],include_lowest = True)

# %%
Customer_Final.head()
# Out:
#    customer_Id        DOB Gender  city_code  transaction_id   cust_id  \
# 0       268408 1970-02-01      M        4.0    8.724384e+10  268408.0
# 1       268408 1970-02-01      M        4.0    1.619787e+10  268408.0
# 2       268408 1970-02-01      M        4.0    1.619787e+10  268408.0
# 3       268408 1970-02-01      M        4.0    2.881014e+10  268408.0
# 4       268408 1970-02-01      M        4.0    6.463344e+10  268408.0
#
#    tran_date  prod_subcat_code  prod_cat_code_x  Qty   Rate      Tax  \
# 0 2014-01-13               7.0              5.0  5.0  187.0   98.175
# 1 2013-12-16               1.0              4.0 -5.0 -210.0  110.250
# 2 2013-12-12               1.0              4.0  5.0  210.0  110.250
# 3 2013-02-09              10.0              6.0  2.0  813.0  170.730
# 4 2013-06-05               4.0              2.0  3.0  312.0   98.280
#
#    total_amt      Store_type  prod_cat_code_y  prod_cat  prod_sub_cat_code  \
# ...

# %%
customer_25_35 = Customer_Final.groupby(['Age_cat','prod_cat'])['total_amt'].sum()
customer_25_35
# Out:
# Age_cat  prod_cat
# 25-35    Bags           1372499.505
#          Books           759603.520
#          Clothing       1441341.005
#          Electronics     609140.090
# 36-46    Bags           1995961.500
#          Books           944245.705
#          Clothing       2029463.995
#          Electronics    1109400.110
# 47-57    Bags            689521.105
#          Books           386267.115
#          Clothing        736099.065
#          Electronics     382307.900
# Name: total_amt, dtype: float64

# %%
customer_25_35.loc['25-35',:]
# Out:
# Age_cat  prod_cat
# 25-35    Bags           1372499.505
#          Books           759603.520
#          Clothing       1441341.005
#          Electronics     609140.090
# Name: total_amt, dtype: float64

# %%
cust_total_amt = Customer_Final[Customer_Final['Age_cat']=='25-35']
cust_total_amt
# Out:
#        customer_Id        DOB Gender  city_code  transaction_id   cust_id  \
# 15010       273686 1985-06-01      F       10.0    2.084250e+10  273686.0
# 15011       273686 1985-06-01      F       10.0    5.178932e+10  273686.0
# 15012       273686 1985-06-01      F       10.0    8.561919e+10  273686.0
# 15013       271174 1985-06-01      F        5.0    1.712248e+10  271174.0
# 15014       271174 1985-06-01      F        5.0    3.770309e+09  271174.0
# ...            ...        ...    ...        ...             ...       ...
# 23189       269626 1992-12-27      F        5.0    7.136903e+10  269626.0
# 23190       269626 1992-12-27      F        5.0    9.413405e+10  269626.0
# 23191       274308 1992-12-29      F        5.0    2.620869e+10  274308.0
# 23192       274308 1992-12-29      F        5.0    5.735882e+10  274308.0
# 23193       274308 1992-12-29      F        5.0    5.816054e+10  274308.0
#
#        tran_date  prod_subcat_code  prod_cat_code_x  Qty    Rate     Tax  \
# ...

# %%
total_amt = cust_total_amt[(cust_total_amt['tran_date']>='2014-01-01') & (cust_total_amt['tran_date']<= '2014-03-01')]
total_amt
# Out:
#        customer_Id        DOB Gender  city_code  transaction_id   cust_id  \
# 15072       272999 1985-05-02      M        5.0    5.948041e+10  272999.0
# 15195       269862 1985-12-03      M        4.0    6.208029e+10  269862.0
# 15362       272757 1985-11-05      M        1.0    2.976029e+09  272757.0
# 15378       274756 1985-05-15      F        9.0    7.959490e+10  274756.0
# 15400       271100 1985-05-23      F        9.0    7.207077e+10  271100.0
# ...            ...        ...    ...        ...             ...       ...
# 23108       271176 1992-05-12      F        6.0    2.547330e+09  271176.0
# 23109       271176 1992-05-12      F        6.0    2.547330e+09  271176.0
# 23119       270695 1992-05-12      F        6.0    2.869675e+10  270695.0
# 23129       268592 1992-06-12      F        7.0    4.584821e+10  268592.0
# 23149       274618 1992-09-12      F        7.0    9.597483e+10  274618.0
#
#        tran_date  prod_subcat_code  prod_cat_code_x  Qty    Rate      Tax  \
# ...

# %%
total_amt['total_amt'].sum()
# Out:
# 540370.415
